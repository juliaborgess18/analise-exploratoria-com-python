# %%
import pandas as pd #importando Pandas
import matplotlib.pyplot as plt #importando Matplotlib
import seaborn as sns #importando Seaborn

# %%
dataFrame = pd.read_excel("AdventureWorks Sales.xlsx") #importando a base Adventure Works
# Out:
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
dataFrame.head(5) #analisando as 5 primeiras linhas da tabela
# Out:
#     Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0  Reseller           43659001     SO43659      SO43659 - 1
# 1  Reseller           43659002     SO43659      SO43659 - 2
# 2  Reseller           43659003     SO43659      SO43659 - 3
# 3  Reseller           43659004     SO43659      SO43659 - 4
# 4  Reseller           43659005     SO43659      SO43659 - 5
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
dataFrame.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\julia\python\analise-exploratoria-adventure-works\analise-adventure-works.ipynb Célula: 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/julia/python/analise-exploratoria-adventure-works/analise-adventure-works.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dataFrame.shape()
#
# TypeError: 'tuple' object is not callable
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
# notebook controller is DISPOSED.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
